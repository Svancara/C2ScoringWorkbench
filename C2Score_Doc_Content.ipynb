# %% [markdown]
# # Content

# %% [markdown]
# [Introduction](./C2Score_Doc_Introduction.ipynb)
#
# [Data Preparation](./C2Score_Doc_DataPreparation.ipynb)
#
# [Life And Death](./C2Score_Doc_LifeAndDeath.ipynb)
#
# [Population Statistics and Metric](./C2Score_Doc_PopulationStats.ipynb)
#
#
# ### Experiments - weekly statistics (C2 data)
#
# - [Age Strategy (Days)](./C2Score_Ages.ipynb)
# - [Alpha](./C2Score_Alpha.ipynb)
# - [Annualized Return Pcnt](./C2Score_AnnReturn.ipynb)
# - [C2Star](./C2Score_C2Star.ipynb)
# - [Cumul Return Pcnt](./C2Score_CumRtndefault.ipynb)
# - [Current Slump as Pcnt Equity](./C2Score_CurrentSlumpAsPcnt.ipynb)
# - [Daily Max Leverage (Avg)](./C2Score_DailyMaxLevMean.ipynb)
# - [Delta Equity 30 Days](./C2Score_Deltaequityp30.ipynb)
# - [Delta Equity 45 Days](./C2Score_Deltaequityp45.ipynb)
# - [JCalmar](./C2Score_JCalmar.ipynb)
# - [Avg(MAE) / Avg(PL) - Losers](./C2Score_MAEtoPL_agg_lose.ipynb)
# - [Avg(MAE) / Avg(PL) - Winners](./C2Score_MAEtoPL_agg_win.ipynb)
# - [Keep After Spread Slippage Percent (every fill pays bid/ask slippage)](./C2Score_KeepAfterSlip.ipynb)
# - [Latest Trade Days Ago](./C2Score_LatestTradeDaysAgo.ipynb)
# - [MaxDrawdown](./C2Score_MaxDrawdown.ipynb)
# - [Max Equity Drawdown (num days)](./C2Score_MaxdrawdownDays.ipynb)
# - [Max Open Loss Percent 45 Days](./C2Score_MaxOpenLossDays45.ipynb)
# - [Max Open Loss Percent 90 Days](./C2Score_MaxOpenLossDays90.ipynb)
# - [Max Open Loss Percent 180 Days](./C2Score_MaxOpenLossDays180.ipynb)
# - [Num Trades All](./C2Score_NumTradesAll.ipynb)
# - [Percentage Months Profitable](./C2Score_PcntMonthsProfit.ipynb)
# - [Percent returns kept after throwing out best month](./C2Score_PcntWithoutBestMonth.ipynb)
# - [Percent Trades Stocks,...](./C2Score_InstrumentsPercent.ipynb)
# - [Last 4 Months - Pcnt Negative](./C2Score_Pcnt_last4Mo_neg.ipynb)
# - [Sharpe Ratio](./C2Score_Sharpe.ipynb)
# - [Short Options - Percent Covered](./C2Score_ShortOptionsCovered.ipynb)
# - [Sortino Ratio](./C2Score_Sortino.ipynb)
# - [TimeSinceHigh_pctAge](./C2Score_TimeSinceHigh_pctAge.ipynb)
#
# [Why age is so important](./C2Score_Doc_Math.ipynb)
#
#
# ### Experiments results
#
# - [ROC 7, 14, 21 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_007-021.html)
# - [ROC 30, 60, 90 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_030-090.html)
# - [ROC 120, 150, 180 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_120-180.html)
# - [ROC 210, 240, 270 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_210-270.html)
# - [ROC 300, 330, 360 days](https://svancara.github.io/C2ScoringWorkbench/ExperimentsResults_300-360.html)
#
#
# ### Usage
#
# [Usage](C2Score_Doc_Usage01.ipynb)
#
#
# #### Tools
#
# [Experiments results](./C2Score_Doc_ExperimentsResults.ipynb)
#
#
#
# ### ToDo:
#
# - Carlton data
# - Model based score
#
# ### Not yet finished drafts: Experiments - daily statistics
#
# - [Annual return](C2Score_AnnReturnDaily.ipynb)
# - [Sharpe](C2Score_SharpeDaily.ipynb)
# - [Sortino](C2Score_SortinoDaily.ipynb)
#
#
# <!---
#
# ### ToDo:
#
# - [C2ScoreCarlton](./C2ScoreCarlton.ipynb)
# - [BobScoreCalmarDraft](./BobScoreCalmarDraft.ipynb)
# - [C2ScoreLinRegRSquared](./C2ScoreLinRegRSquared.ipynb)
# - [C2ScoreProfitDivMaxdd](./C2ScoreProfitDivMaxdd.ipynb)
#
#
# C2Score_Sharpe-Investigation-Details.ipynb
#
#
# - [BobScoreDescription](./BobScoreDescription.ipynb)
#
#
# private
#
# - [VaR_gaussian](./C2ScoreVar_gaussian.ipynb)
# - [VaR_historical](./C2ScoreVaR_historical.ipynb)
# - [Var_modified](./C2ScoreVar_modified.ipynb)
# - [jen jsem neco zacal okolo Collective2 Sharpe](./Untitled1.ipynb)
#
# private [MonthlyPopulationStats](./C2Score_MonthlyPopulationStats.ipynb)
#
# private [LiveAndDeadSystems_deprecated_failed_investigation](./LiveAndDeadSystems_deprecated_failed_investigation.ipynb)
#
# private [Part1_deprecated](./C2ScorePart1_deprecated.ipynb)
#
# private [Part2Daily](./C2ScorePart2Daily.ipynb)
#
# private [Part3-Copy1](./C2ScorePart3-Copy1.ipynb)
#
# private [C2Score_Doc_Learning_HypothesisTests_PrivateDoc.ipynb](./C2Score_Doc_Learning_HypothesisTests_PrivateDoc.ipynb)
#
# private [PopulationBasicSelectionByAge](./C2Score_PopulationBasicSelectionByAge.ipynb)
#
# private C2Score_UnitTest.ipynb
#
# private  [C2ScoreProfitDivMaxdd](C2ScoreProfitDivMaxdd.ipynb)
#
# -->
