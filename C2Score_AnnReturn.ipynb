# %% [markdown]
# # Annualized Return Pcnt
#
# ## Collective2 data
#
# Use `Age > 90` for the daily data research compatibility.

# %%
source("JupyterUtils.R")
source("C2ScoreHypothesisPresentation.R")

# %%
# What data we have.
sql = "select systemid, YYYYMMDD, statval
            from historical_stats_modern h
            join c2systems sys on sys.guid=h.systemid 
            where statname='cARdefault' 
                  and (DATEDIFF(cast(date_format(YYYYMMDD,'%Y%m%d') AS Date), Date(from_unixtime(added))) + 1) > 90"

dbData = getC2ScoreDbData(sql)
overview(dbData)
hist(dbData$statval,breaks=50)
# Out:
#      Systems    Obsrvtns     Minimum     1st Qu.      Median        Mean     3rd Qu.     Maximum          SD
#         3957      150420     -1.0000     -0.0681      0.1153  83036.1595      0.4208       1e+098715343.9002
# Plot with title “Histogram of dbData$statval”

# %% [markdown]
# Based on the [previous investigation](./C2Score_AnnReturn_Crazy.ipynb), this statistics is not in percents.

# %%
# Ann return between 10 and 100%

sql = "select systemid, YYYYMMDD, statval
            from historical_stats_modern h
            join c2systems sys on sys.guid=h.systemid 
            where statname='cARdefault' 
                  and (DATEDIFF(cast(date_format(YYYYMMDD,'%Y%m%d') AS Date), Date(from_unixtime(added))) + 1) > 90
                  and statval >= 0.1 and statval <= 1.0"
dbData = getC2ScoreDbData(sql)
overview(dbData)
hist(dbData$statval,breaks=50)
# Out:
#      Systems    Obsrvtns     Minimum     1st Qu.      Median        Mean     3rd Qu.     Maximum          SD
#         1968       60245      0.1000      0.1852      0.3058      0.3686      0.4977      1.0000      0.2257
# Plot with title “Histogram of dbData$statval”

# %%
# Join with our cleaned data
sql = "select statval, eq.*
       from ReturnsDataInIntervalsCleanedSkip090 eq
       join historical_stats_modern h on h.systemid=eq.systemid and h.YYYYMMDD = cast(date_format(DateStart,'%Y%m%d') AS UNSIGNED)
       where statname='cARdefault' and statval >= 0.1 and statval <= 1.0 and Age > 90"

dbData = getC2ScoreDbData(sql)
overview(dbData)
hist(dbData$statval,breaks=50)
# Out:
#      Systems    Obsrvtns     Minimum     1st Qu.      Median        Mean     3rd Qu.     Maximum          SD
#         1119       27930      0.1000      0.1957      0.3171      0.3745      0.5044      1.0000      0.2224
# Plot with title “Histogram of dbData$statval”

# %%
experiment = list(
  name = "Annualized Return Pcnt (C2 data, Age > 90)",
  description = "Investigate AnnReturn. Age > 90",
  sqlText = sql, # the latest sql above
  attributeName = "statval",
  attributeSteps = seq(from = 0.1, to = 1.0, by = 0.1),
  comparisonOperator = `>`)

result = makeExperiment(experiment)
# Out:
# We have calculated and stored the whole population statistics of strategies daily returns after 7, 14, ..., 360 days. Day after day. Now, we selected a particular statistics data (a sample) from the whole population. Collective2 data are joined with a cleaned strategies set used for the population calculations. We want to know, if the average of returns of the sample is significantly higher than an average of returns of the whole population. A significance level is  0.05 .
#
# The following table contains this hypothesis tests for defined stats intervals and all 7, 14, ..., 360 days time intervals.
#
#
# Descriptive stats of all data selected in the experiment:
#      Systems    Obsrvtns     Minimum     1st Qu.      Median        Mean     3rd Qu.     Maximum          SD
#         1119       27930      0.1000      0.1957      0.3171      0.3745      0.5044      1.0000      0.2224
# plot without title
# plot without title

# %%
showSDLessHypothesisTest(experiment, result)
# Out:
# Hypothesis test of sample standard deviation.
#
# Alternative hypothesis: The sample standard deviation is less than the population SD.
# plot without title

# %%
showObservationsCounts(experiment, result)
# Out:
# The following table contains numbers of observations in the used statistics intervals.
# A number of observations in the sample is an important part of the hypothesis testing. Be careful if it is low (less than 30).
# Collective2 data are calculated in 7-days intervals. It means we have less observations which decreases hypotesis testing reliability. Use daily data tests if available.
# Numbers of observations shown in this table are NOT numbers of C2 strategies! Every strategy can have many observations in any statistics interval. That is what is shown here.
#   Selection            Obs007 Obs014 Obs021 Obs030 Obs060 Obs090 Obs120 Obs150
# 1 0.9 <= statval < 1    791    772    761    737    664    593    535    480
# 2 0.8 <= statval < 0.9  994    974    950    923    825    734    658    599
# 3 0.7 <= statval < 0.8 1257   1231   1204   1171   1058    935    865    794
# 4 0.6 <= statval < 0.7 1651   1622   1583   1532   1400   1271   1163   1049
# 5 0.5 <= statval < 0.6 2239   2173   2123   2060   1835   1626   1429   1260
# 6 0.4 <= statval < 0.5 3019   2952   2873   2772   2460   2202   1990   1784
# 7 0.3 <= statval < 0.4 4532   4452   4357   4255   3850   3437   3077   2772
# 8 0.2 <= statval < 0.3 5717   5559   5417   5241   4694   4218   3783   3450
# 9 0.1 <= statval < 0.2 7052   6852   6681   6475   5781   5153   4653   4174
#   Obs180 Obs210 Obs240 Obs270 Obs300 Obs330 Obs360
# 1  417    377    350    317    299    269    231
# 2  545    499    437    385    344    300    268
# 3  726    656    571    523    451    382    344
# 4  955    870    788    686    576    511    466
# 5 1098    989    871    755    694    645    591
# 6 1593   1423   1282   1198   1130   1053    984
# 7 2491   2282   2102   1939   1775   1664   1562
# 8 3157   2893   2634   2391   2154   1976   1814
# 9 3741   3402   3088   2806   2573   2376   2199

# %%
showMetricDifferences(experiment, result)
# Out:
# SampleMetricValue minus PopulationMetricValue
#
# This table shows differences between metric values calculated for the whole population and the current sample metric values. (See the chapter 'Population statistics'.)
# This is different from our hypothesis test. Our hypothesis test tests an (alternative) hypothesis 'Is a mean of the sample greater than a mean of the population?'
# But our metric is 'Mean divided by SD'. So the standard deviation plays a role in it.
# Our metric is greater when a numerator is greater and/or denominator is less. It is up to you what you prefer.
# plot without title

# %%
showSystemsCounts(experiment, result)
# Out:
# Numbers of strategies observed in defined intervals.
#   Selection            Sys007 Sys014 Sys021 Sys030 Sys060 Sys090 Sys120 Sys150
# 1 0.9 <= statval < 1   265    255    253    245    212    184    169    155
# 2 0.8 <= statval < 0.9 300    291    279    269    234    206    181    161
# 3 0.7 <= statval < 0.8 333    321    313    296    258    220    198    174
# 4 0.6 <= statval < 0.7 393    381    364    345    301    269    240    213
# 5 0.5 <= statval < 0.6 454    433    421    409    349    302    267    228
# 6 0.4 <= statval < 0.5 518    505    493    471    395    338    299    267
# 7 0.3 <= statval < 0.4 574    550    533    514    433    378    322    291
# 8 0.2 <= statval < 0.3 604    575    561    539    466    404    348    296
# 9 0.1 <= statval < 0.2 664    621    604    580    476    406    360    314
#   Sys180 Sys210 Sys240 Sys270 Sys300 Sys330 Sys360
# 1 131    119    105     91     82     74     67
# 2 139    130    113    101     87     74     64
# 3 153    140    116    109     96     81     70
# 4 188    164    144    128    110     99     87
# 5 194    171    150    126    116    102     91
# 6 234    197    164    144    132    119    104
# 7 247    210    190    170    143    129    118
# 8 262    231    205    179    157    144    134
# 9 273    239    211    186    167    153    137

# %% [markdown]
# ### Discussion
#
# ..................... (The same as in daily data?)

# %% [markdown]
# ## Age > 180

# %%
sql = "select statval, eq.*
       from ReturnsDataInIntervalsCleanedSkip090 eq
       join historical_stats_modern h on h.systemid=eq.systemid and h.YYYYMMDD = cast(date_format(DateStart,'%Y%m%d') AS UNSIGNED)
       where statname='cARdefault' and statval >= 0.1 and statval <= 1.0 and Age > 180"

dbData = getC2ScoreDbData(sql)
overview(dbData)
hist(dbData$statval,breaks=50)
# Out:
#      Systems    Obsrvtns     Minimum     1st Qu.      Median        Mean     3rd Qu.     Maximum          SD
#          680       21989      0.1000      0.1904      0.3049      0.3617      0.4817      1.0000      0.2146
# Plot with title “Histogram of dbData$statval”

# %%
experiment = list(
  name = "Annualized Return Pcnt (C2 data, Age > 180)",
  description = "Investigate AnnReturn. Age > 180",
  sqlText = sql, # the latest sql above
  attributeName = "statval",
  attributeSteps = seq(from = 0.1, to = 1.0, by = 0.1),
  comparisonOperator = `>`)

result = makeExperiment(experiment)
# Out:
# We have calculated and stored the whole population statistics of strategies daily returns after 7, 14, ..., 360 days. Day after day. Now, we selected a particular statistics data (a sample) from the whole population. Collective2 data are joined with a cleaned strategies set used for the population calculations. We want to know, if the average of returns of the sample is significantly higher than an average of returns of the whole population. A significance level is  0.05 .
#
# The following table contains this hypothesis tests for defined stats intervals and all 7, 14, ..., 360 days time intervals.
#
#
# Descriptive stats of all data selected in the experiment:
#      Systems    Obsrvtns     Minimum     1st Qu.      Median        Mean     3rd Qu.     Maximum          SD
#          680       21989      0.1000      0.1904      0.3049      0.3617      0.4817      1.0000      0.2146
# plot without title
# plot without title

# %%
showSDLessHypothesisTest(experiment, result)
# Out:
# Hypothesis test of sample standard deviation.
#
# Alternative hypothesis: The sample standard deviation is less than the population SD.
# plot without title

# %%
showObservationsCounts(experiment, result)
# Out:
# The following table contains numbers of observations in the used statistics intervals.
# A number of observations in the sample is an important part of the hypothesis testing. Be careful if it is low (less than 30).
# Collective2 data are calculated in 7-days intervals. It means we have less observations which decreases hypotesis testing reliability. Use daily data tests if available.
# Numbers of observations shown in this table are NOT numbers of C2 strategies! Every strategy can have many observations in any statistics interval. That is what is shown here.
#   Selection            Obs007 Obs014 Obs021 Obs030 Obs060 Obs090 Obs120 Obs150
# 1 0.9 <= statval < 1    495    486    479    467    431    392    348    310
# 2 0.8 <= statval < 0.9  676    665    658    642    586    529    473    434
# 3 0.7 <= statval < 0.8  933    921    904    890    822    733    680    630
# 4 0.6 <= statval < 0.7 1234   1215   1196   1163   1079    986    911    819
# 5 0.5 <= statval < 0.6 1699   1657   1622   1576   1425   1272   1121    993
# 6 0.4 <= statval < 0.5 2318   2272   2219   2155   1954   1753   1607   1455
# 7 0.3 <= statval < 0.4 3644   3592   3525   3448   3159   2846   2579   2338
# 8 0.2 <= statval < 0.3 4690   4572   4468   4336   3920   3563   3248   2983
# 9 0.1 <= statval < 0.2 5840   5700   5569   5415   4889   4387   3982   3599
#   Obs180 Obs210 Obs240 Obs270 Obs300 Obs330 Obs360
# 1  266    238    222    205    197    178    154
# 2  401    364    324    291    265    236    214
# 3  576    524    464    430    373    321    292
# 4  748    687    634    556    471    418    384
# 5  869    788    701    622    576    543    501
# 6 1318   1191   1092   1032    982    924    869
# 7 2111   1955   1805   1684   1568   1475   1391
# 8 2735   2521   2324   2123   1913   1753   1599
# 9 3241   2966   2709   2489   2295   2121   1967

# %%
showMetricDifferences(experiment, result)
# Out:
# SampleMetricValue minus PopulationMetricValue
#
# This table shows differences between metric values calculated for the whole population and the current sample metric values. (See the chapter 'Population statistics'.)
# This is different from our hypothesis test. Our hypothesis test tests an (alternative) hypothesis 'Is a mean of the sample greater than a mean of the population?'
# But our metric is 'Mean divided by SD'. So the standard deviation plays a role in it.
# Our metric is greater when a numerator is greater and/or denominator is less. It is up to you what you prefer.
# plot without title

# %%
showSystemsCounts(experiment, result)
# Out:
# Numbers of strategies observed in defined intervals.
#   Selection            Sys007 Sys014 Sys021 Sys030 Sys060 Sys090 Sys120 Sys150
# 1 0.9 <= statval < 1   138    134    134    130    118    110     99     92
# 2 0.8 <= statval < 0.9 163    158    157    152    134    123    109     97
# 3 0.7 <= statval < 0.8 193    192    189    183    171    149    133    122
# 4 0.6 <= statval < 0.7 220    215    213    206    189    170    154    131
# 5 0.5 <= statval < 0.6 251    245    240    232    207    182    165    145
# 6 0.4 <= statval < 0.5 294    287    281    270    245    203    191    173
# 7 0.3 <= statval < 0.4 337    328    319    311    271    235    212    193
# 8 0.2 <= statval < 0.3 387    374    369    356    308    260    225    202
# 9 0.1 <= statval < 0.2 429    408    398    384    324    270    240    211
#   Sys180 Sys210 Sys240 Sys270 Sys300 Sys330 Sys360
# 1  75     65     57     51     49     44     40
# 2  89     81     71     65     59     51     47
# 3 107    101     83     82     75     63     57
# 4 117    104     97     87     77     66     60
# 5 127    114    102     90     80     74     66
# 6 151    127    106     96     90     82     73
# 7 158    138    120    113     99     91     84
# 8 180    158    143    127    110    102     95
# 9 180    163    145    131    120    109    100

# %% [markdown]
# ### Discussion
#
# ..............
